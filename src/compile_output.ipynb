# %%
# Author: Konstantin
# Modified by: Adrielli

import os
import re
import json
import argparse
from typing import List, Tuple
import pandas as pd, ast

# pd.set_option("display.max_colwidth", None)
# pd.set_option("display.max_rows", None)   
# pd.set_option("display.max_columns", None)

# %%
allowed_text_type = 'wed'
allowed_text_model = 'relik-cie-small'
allowed_text_corpus = 'meco'

model_name = re.escape(allowed_text_model)
pattern = rf"output_step_(\d+)_{model_name}_([^_]+)_.*\.json"

filename_re = re.compile(pattern, re.IGNORECASE)

# %%
files_by_type = {}
for file_name in os.listdir("."):
    match = filename_re.match(file_name)
    if not match:
        continue
    step_num = int(match.group(1))
    text_type = match.group(2).lower()
    if text_type != allowed_text_type:
        continue
    else:
        files_by_type.setdefault(text_type, []).append((step_num, file_name))
print("Files by type:", files_by_type)
# Out:
# Files by type: {'wed': [(1, 'output_step_001_relik-cie-small_WED_0.1_128.json'), (2, 'output_step_002_relik-cie-small_WED_0.1_128.json'), (3, 'output_step_003_relik-cie-small_WED_0.1_128.json'), (4, 'output_step_004_relik-cie-small_WED_0.1_128.json'), (5, 'output_step_005_relik-cie-small_WED_0.1_128.json'), (6, 'output_step_006_relik-cie-small_WED_0.1_128.json'), (7, 'output_step_007_relik-cie-small_WED_0.1_128.json'), (8, 'output_step_008_relik-cie-small_WED_0.1_128.json'), (9, 'output_step_009_relik-cie-small_WED_0.1_128.json'), (10, 'output_step_010_relik-cie-small_WED_0.1_128.json'), (11, 'output_step_011_relik-cie-small_WED_0.1_128.json'), (12, 'output_step_012_relik-cie-small_WED_0.1_128.json'), (13, 'output_step_013_relik-cie-small_WED_0.1_128.json'), (14, 'output_step_014_relik-cie-small_WED_0.1_128.json'), (15, 'output_step_015_relik-cie-small_WED_0.1_128.json'), (16, 'output_step_016_relik-cie-small_WED_0.1_128.json'), (17, 'output_step_017_relik-cie-small_WED_0.1_128.json'), (18, 'output_step_018_relik-cie-small_WED_0.1_128.json'), (19, 'output_step_019_relik-cie-small_WED_0.1_128.json'), (20, 'output_step_020_relik-cie-small_WED_0.1_128.json'), (21, 'output_step_021_relik-cie-small_WED_0.1_128.json'), (22, 'output_step_022_relik-cie-small_WED_0.1_128.json'), (23, 'output_step_023_relik-cie-small_WED_0.1_128.json'), (24, 'output_step_024_relik-cie-small_WED_0.1_128.json'), (25, 'output_step_025_relik-cie-small_WED_0.1_128.json'), (26, 'output_step_026_relik-cie-small_WED_0.1_128.json'), (27, 'output_step_027_relik-cie-small_WED_0.1_128.json'), (28, 'output_step_028_relik-cie-small_WED_0.1_128.json'), (29, 'output_step_029_relik-cie-small_WED_0.1_128.json'), (30, 'output_step_030_relik-cie-small_WED_0.1_128.json'), (31, 'output_step_031_relik-cie-small_WED_0.1_128.json'), (32, 'output_step_032_relik-cie-small_WED_0.1_128.json'), (33, 'output_step_033_relik-cie-small_WED_0.1_128.json'), (34, 'output_step_034_relik-cie-small_WED_0.1_128.json'), (35, 'output_step_035_relik-cie-small_WED_0.1_128.json'), (36, 'output_step_036_relik-cie-small_WED_0.1_128.json'), (37, 'output_step_037_relik-cie-small_WED_0.1_128.json'), (38, 'output_step_038_relik-cie-small_WED_0.1_128.json'), (39, 'output_step_039_relik-cie-small_WED_0.1_128.json'), (40, 'output_step_040_relik-cie-small_WED_0.1_128.json'), (41, 'output_step_041_relik-cie-small_WED_0.1_128.json'), (42, 'output_step_042_relik-cie-small_WED_0.1_128.json'), (43, 'output_step_043_relik-cie-small_WED_0.1_128.json'), (44, 'output_step_044_relik-cie-small_WED_0.1_128.json'), (45, 'output_step_045_relik-cie-small_WED_0.1_128.json'), (46, 'output_step_046_relik-cie-small_WED_0.1_128.json'), (47, 'output_step_047_relik-cie-small_WED_0.1_128.json'), (48, 'output_step_048_relik-cie-small_WED_0.1_128.json'), (49, 'output_step_049_relik-cie-small_WED_0.1_128.json'), (50, 'output_step_050_relik-cie-small_WED_0.1_128.json'), (51, 'output_step_051_relik-cie-small_WED_0.1_128.json'), (52, 'output_step_052_relik-cie-small_WED_0.1_128.json'), (53, 'output_step_053_relik-cie-small_WED_0.1_128.json'), (54, 'output_step_054_relik-cie-small_WED_0.1_128.json'), (55, 'output_step_055_relik-cie-small_WED_0.1_128.json'), (56, 'output_step_056_relik-cie-small_WED_0.1_128.json'), (57, 'output_step_057_relik-cie-small_WED_0.1_128.json'), (58, 'output_step_058_relik-cie-small_WED_0.1_128.json'), (59, 'output_step_059_relik-cie-small_WED_0.1_128.json'), (60, 'output_step_060_relik-cie-small_WED_0.1_128.json'), (61, 'output_step_061_relik-cie-small_WED_0.1_128.json'), (62, 'output_step_062_relik-cie-small_WED_0.1_128.json'), (63, 'output_step_063_relik-cie-small_WED_0.1_128.json'), (64, 'output_step_064_relik-cie-small_WED_0.1_128.json'), (65, 'output_step_065_relik-cie-small_WED_0.1_128.json'), (66, 'output_step_066_relik-cie-small_WED_0.1_128.json'), (67, 'output_step_067_relik-cie-small_WED_0.1_128.json'), (68, 'output_step_068_relik-cie-small_WED_0.1_128.json'), (69, 'output_step_069_relik-cie-small_WED ...

# %%
rows_add = []
rows_drop = []
rows_all = []
for text_type, files in files_by_type.items():
    files.sort(key=lambda x: x[0])
    prev_set = set()
    seen_ever = set()

    for step, file_name in files:
        with open(file_name, encoding="utf-8") as f:
            data = json.load(f)

        simplified_triplets = []
        triplet_scores = []
        for raw in data.get("triplets", []):
            # raw is [head, rel, tail, score]
            head, rel, tail, *rest = raw
            score = rest[0] if rest else None
        
            # HEAD 
            if isinstance(head, list):
                canon_h = head[2] if len(head) > 2 else ""
                surface_h = head[3] if len(head) > 3 else ""
                head_name = f"{canon_h} | {surface_h}" if surface_h and surface_h != canon_h else canon_h
            else:
                head_name = str(head)

            # TAIL
            if isinstance(tail, list):
                canon_t = tail[2] if len(tail) > 2 else ""
                surface_t = tail[3] if len(tail) > 3 else ""
                tail_name = f"{canon_t} | {surface_t}" if surface_t and surface_t != canon_t else canon_t
            else:
                tail_name = str(tail)

            simplified_triplets.append((head_name, rel, tail_name))
            triplet_scores.append(score)
        # print("Simplified triplets:", simplified_triplets)

        curr_set = set(simplified_triplets)
        impacted = curr_set != prev_set
        added_trips = [t for t in curr_set if t not in prev_set]
        dropped_trips = [t for t in prev_set if t not in curr_set]

        rows_all.append({
            "text_type": text_type,
            "output_step": step,
            "current_word": data["text"].split()[-1],
            "triplet_impacted": "yes" if impacted else "no",
            "current_text": data["text"],
            "total_triplets": simplified_triplets,
            "triplet_scores": triplet_scores
        })

        new_trips = [t for t in added_trips if t not in seen_ever]

        if new_trips:
            seen_ever.update(new_trips)
            rows_add.append({
                "text_type": text_type,
                "output_step": step,
                "current_word": data["text"].split()[-1],
                "current_text": data["text"],
                "new_triplets": new_trips,
                "total_triplets": simplified_triplets,
                "triplet_scores": triplet_scores,
            })

        if dropped_trips:
            rows_drop.append({
                "text_type": text_type,
                "output_step": step,
                "current_word": data["text"].split()[-1],
                "current_text": data["text"],
                "dropped_triplets": dropped_trips,
                "total_triplets": simplified_triplets,
                "triplet_scores": triplet_scores,
            })

        prev_set = curr_set

# %%
df_full = (pd.DataFrame(rows_all).sort_values(["text_type","output_step"]).reset_index(drop=True))
display(df_full)
df_full.to_csv(f"full_{allowed_text_model}_{allowed_text_corpus}_{allowed_text_type}.csv", index=False)
# Out:
#     text_type  output_step current_word triplet_impacted  \
# 0         wed            1        World               no
# 1         wed            2  Environment               no
# 2         wed            3          Day               no
# 3         wed            4        (WED)               no
# 4         wed            5           is               no
# ..        ...          ...          ...              ...
# 159       wed          160      plastic              yes
# 160       wed          161           in              yes
# 161       wed          162        India              yes
# 162       wed          163           by               no
# 163       wed          164        2022.               no
#
#                                           current_text  \
# 0                                                World
# 1                                    World Environment
# 2                                World Environment Day
# 3                          World Environment Day (WED)
# 4                       World Environment Day (WED) is
# ..                                                 ...
# 159  World Environment Day (WED) is celebrated on t...
# 160  World Environment Day (WED) is celebrated on t...
# 161  World Environment Day (WED) is celebrated on t...
# 162  World Environment Day (WED) is celebrated on t...
# 163  World Environment Day (WED) is celebrated on t...
#
#                                         total_triplets  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 159  [(United Nations | United Nation, statement is...
# 160  [(United Nations | United Nation, statement is...
# 161  [(United Nations | United Nation, statement is...
# 162  [(United Nations | United Nation, statement is...
# 163  [(United Nations | United Nation, statement is...
#
#                                         triplet_scores
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 159  [0.15000000596046448, 0.10000000149011612, 0.1...
# 160  [0.15000000596046448, 0.10000000149011612, 0.1...
# 161  [0.15000000596046448, 0.10000000149011612, 0.1...
# 162  [0.15000000596046448, 0.10000000149011612, 0.1...
# 163  [0.15000000596046448, 0.10000000149011612, 0.1...
#
# [164 rows x 7 columns]

# %%
additions_df = pd.DataFrame(rows_add).sort_values("output_step").reset_index(drop=True)
display(additions_df)
additions_df.to_csv(f"additions_{allowed_text_model}_{allowed_text_corpus}_{allowed_text_type}.csv", index=False)
# Out:
#    text_type  output_step     current_word  \
# 0        wed           19        principal
# 1        wed           20          vehicle
# 2        wed           24              and
# 3        wed           51       pollution,
# 4        wed           53  overpopulation,
# 5        wed           57              WED
# 6        wed           61           become
# 7        wed           78              WED
# 8        wed           79          chooses
# 9        wed           87   organizations,
# 10       wed           88     communities,
# 11       wed           90              and
# 12       wed           91      celebrities
# 13       wed           96    environmental
# 14       wed           97          causes.
# 15       wed          103             2018
# 16       wed          104               is
# 17       wed          106          Plastic
# 18       wed          107       Pollution.
# 19       wed          110               is
# 20       wed          111               to
# 21       wed          113           people
# 22       wed          115           change
# 23       wed          117         everyday
# 24       wed          119               in
# 25       wed          122              can
# 26       wed          128         campaign
# 27       wed          129            hopes
# 28       wed          136               or
# 29       wed          139           items,
# 30       wed          143           severe
# 31       wed          153       government
# 32       wed          155          pledged
# 33       wed          157        eliminate
# 34       wed          158              all
# 35       wed          161               in
# 36       wed          162            India
#
#                                          current_text  \
# 0   World Environment Day (WED) is celebrated on t...
# 1   World Environment Day (WED) is celebrated on t...
# 2   World Environment Day (WED) is celebrated on t...
# 3   World Environment Day (WED) is celebrated on t...
# 4   World Environment Day (WED) is celebrated on t...
# 5   World Environment Day (WED) is celebrated on t...
# 6   World Environment Day (WED) is celebrated on t...
# 7   World Environment Day (WED) is celebrated on t...
# 8   World Environment Day (WED) is celebrated on t...
# 9   World Environment Day (WED) is celebrated on t...
# 10  World Environment Day (WED) is celebrated on t...
# 11  World Environment Day (WED) is celebrated on t...
# 12  World Environment Day (WED) is celebrated on t...
# 13  World Environment Day (WED) is celebrated on t...
# 14  World Environment Day (WED) is celebrated on t...
# 15  World Environment Day (WED) is celebrated on t...
# 16  World Environment Day (WED) is celebrated on t...
# 17  World Environment Day (WED) is celebrated on t...
# 18  World Environment Day (WED) is celebrated on t...
# 19  World Environment Day (WED) is celebrated on t...
# 20  World Environment Day (WED) is celebrated on t...
# 21  World Environment Day (WED) is celebrated on t...
# 22  World Environment Day (WED) is celebrated on t...
# 23  World Environment Day (WED) is celebrated on t...
# 24  World Environment Day (WED) is celebrated on t...
# 25  World Environment Day (WED) is celebrated on t...
# 26  World Environment Day (WED) is celebrated on t...
# 27  World Environment Day (WED) is celebrated on t...
# 28  World Environment Day (WED) is celebrated on t...
# 29  World Environment Day (WED) is celebrated on t...
# 30  World Environment Day (WED) is celebrated on t...
# 31  World Environment Day (WED) is celebrated on t...
# 32  World Environment Day (WED) is celebrated on t...
# 33  World Environment Day (WED) is celebrated on t...
# 34  World Environment Day (WED) is celebrated on t...
# 35  World Environment Day (WED) is celebrated on t...
# 36  World Environment Day (WED) is celebrated on t...
#
#                                          new_triplets  \
# 0   [(World Environment Day | WED, conferred by, U...
# 1   [(World Environment Day | WED, conferred by, U...
# 2   [(World Wildlife Day | WED, conferred by, Unit...
# 3   [(Marine pollution | marine pollution, stateme...
# 4   [(Human overpopulation | human overpopulation,...
# 5   [(United Nations | United Nation, significant ...
# 6   [(United Nations | United Nation, statement is...
# 7   [(World Environment Day | WED, instance of, Wo...
# 8       [(--NME-- | WED, instance of, --NME-- | WED)]
# 9   [(--NME-- | marine pollution, statement is sub...
# 10  [(--NME-- | non-governmental organizations, pa...
# 11  [(Human overpopulation | human overpopulation,...
# 12  [(--NME-- | marine pollution, statement is sub...
# 13  [(United Nations | United Nation, statement is...
# 14  [(--NME-- | governments, part of, United Natio...
# 15  [(--NME-- | marine pollution, facet of, Climat...
# 16  [(Human overpopulation | human overpopulation,...
# 17  [(Plastic pollution | marine pollution, statem...
# 18  [(Plastic pollution | marine pollution, facet ...
# 19  [(Climate change | global warming, has cause, ...
# 20  [(Climate change | global warming, has cause, ...
# 21  [(--NME-- | governments, facet of, --NME-- | W...
# 22  [(--NME-- | governments, facet of, United Nati...
# 23  [(March for Science 2018 | WED, part of, Unite...
# 24  [(Climate change | global warming, statement i...
# 25  [(Overpopulation | human overpopulation, facet...
# 26  [(Plastic pollution | plastic pollution, has c...
# 27  [(--NME-- | non-governmental organizations, fa...
# 28      [(--NME-- | WED, start time, --NME-- | 1974)]
# 29  [(--NME-- | WED chooses a new theme that major...
# 30  [(--NME-- | governments, facet of, Climate cha...
# 31  [(Marine plastic pollution | marine pollution,...
# 32  [(--NME-- | WED chooses a new theme that major...
# 33  [(Climate change | global warming, has cause, ...
# 34  [(Climate change | global warming, has cause, ...
# 35  [(--NME-- | non-governmental organizations, fa...
# 36  [(--NME-- | governments, country, India), (--N...
#
#                                        total_triplets  \
# 0   [(World Environment Day, conferred by, United ...
# 1   [(World Environment Day, conferred by, United ...
# 2   [(World Environment Day, conferred by, United ...
# 3   [(World Environment Day, conferred by, United ...
# 4   [(World Environment Day, conferred by, United ...
# 5   [(United Nations | United Nation, significant ...
# 6   [(United Nations | United Nation, statement is...
# 7   [(Human overpopulation | human overpopulation,...
# 8   [(Climate change | global warming, statement i...
# 9   [(--NME-- | marine pollution, statement is sub...
# 10  [(United Nations | United Nation, statement is...
# 11  [(--NME-- | marine pollution, statement is sub...
# 12  [(--NME-- | marine pollution, statement is sub...
# 13  [(United Nations | United Nation, statement is...
# 14  [(United Nations | United Nation, statement is...
# 15  [(United Nations | United Nation, statement is...
# 16  [(--NME-- | marine pollution, statement is sub...
# 17  [(United Nations | United Nation, statement is...
# 18  [(United Nations | United Nation, statement is...
# 19  [(United Nations | United Nation, statement is...
# 20  [(United Nations | United Nation, statement is...
# 21  [(United Nations | United Nation, statement is...
# 22  [(United Nations | United Nation, statement is...
# 23  [(United Nations | United Nation, statement is...
# 24  [(United Nations | United Nation, statement is...
# 25  [(United Nations | United Nation, statement is...
# 26  [(United Nations | United Nation, statement is...
# 27  [(United Nations | United Nation, statement is...
# 28  [(United Nations | United Nation, statement is...
# 29  [(United Nations | United Nation, statement is...
# 30  [(United Nations | United Nation, statement is...
# 31  [(United Nations | United Nation, statement is...
# 32  [(United Nations | United Nation, statement is...
# 33  [(United Nations | United Nation, statement is...
# 34  [(United Nations | United Nation, statement is...
# 35  [(United Nations | United Nation, statement is...
# 36  [(United Nations | United Nation, statement is...
#
#                                        triplet_scores
# 0          [0.18000000715255737, 0.17000000178813934]
# 1             [0.5299999713897705, 0.550000011920929]
# 2           [0.3799999952316284, 0.36000001430511475]
# 3   [0.47999998927116394, 0.25999999046325684, 0.1...
# 4   [0.6299999952316284, 0.4000000059604645, 0.109...
# 5   [0.1599999964237213, 0.10999999940395355, 0.12...
# 6   [0.10000000149011612, 0.15000000596046448, 0.1...
# 7   [0.1899999976158142, 0.3100000023841858, 0.119...
# 8          [0.20000000298023224, 0.23000000417232513]
# 9   [0.10999999940395355, 0.14000000059604645, 0.6...
# 10  [0.10999999940395355, 0.11999999731779099, 0.1...
# 11  [0.12999999523162842, 0.1899999976158142, 0.10...
# 12  [0.12999999523162842, 0.10000000149011612, 0.1...
# 13  [0.14000000059604645, 0.10999999940395355, 0.2...
# 14  [0.12999999523162842, 0.10999999940395355, 0.2...
# 15  [0.10999999940395355, 0.17000000178813934, 0.1...
# 16  [0.1599999964237213, 0.10999999940395355, 0.17...
# 17  [0.17000000178813934, 0.23000000417232513, 0.1...
# 18  [0.1899999976158142, 0.12999999523162842, 0.20...
# 19  [0.15000000596046448, 0.10000000149011612, 0.2...
# 20  [0.15000000596046448, 0.10000000149011612, 0.2...
# 21  [0.15000000596046448, 0.10000000149011612, 0.2...
# 22  [0.15000000596046448, 0.10000000149011612, 0.1...
# 23  [0.15000000596046448, 0.10000000149011612, 0.2...
# 24  [0.15000000596046448, 0.10000000149011612, 0.1...
# 25  [0.15000000596046448, 0.10000000149011612, 0.1...
# 26  [0.15000000596046448, 0.10000000149011612, 0.1...
# 27  [0.15000000596046448, 0.10000000149011612, 0.1...
# 28  [0.15000000596046448, 0.10000000149011612, 0.2...
# 29  [0.15000000596046448, 0.10000000149011612, 0.1...
# 30  [0.15000000596046448, 0.10000000149011612, 0.1...
# 31  [0.15000000596046448, 0.10000000149011612, 0.1...
# 32  [0.15000000596046448, 0.10000000149011612, 0.2...
# 33  [0.15000000596046448, 0.10000000149011612, 0.1...
# 34  [0.15000000596046448, 0.10000000149011612, 0.1...
# 35  [0.15000000596046448, 0.10000000149011612, 0.1...
# 36  [0.15000000596046448, 0.10000000149011612, 0.1...

# %%
deletions_df = pd.DataFrame(rows_drop).sort_values("output_step").reset_index(drop=True)
display(deletions_df)
deletions_df.to_csv(f"deletions_{allowed_text_model}_{allowed_text_corpus}_{allowed_text_type}.csv", index=False)
# Out:
#    text_type  output_step current_word  \
# 0        wed           20      vehicle
# 1        wed           21          for
# 2        wed           24          and
# 3        wed           25       action
# 4        wed           26          for
# ..       ...          ...          ...
# 60       wed          157    eliminate
# 61       wed          158          all
# 62       wed          159   single-use
# 63       wed          160      plastic
# 64       wed          162        India
#
#                                          current_text  \
# 0   World Environment Day (WED) is celebrated on t...
# 1   World Environment Day (WED) is celebrated on t...
# 2   World Environment Day (WED) is celebrated on t...
# 3   World Environment Day (WED) is celebrated on t...
# 4   World Environment Day (WED) is celebrated on t...
# ..                                                ...
# 60  World Environment Day (WED) is celebrated on t...
# 61  World Environment Day (WED) is celebrated on t...
# 62  World Environment Day (WED) is celebrated on t...
# 63  World Environment Day (WED) is celebrated on t...
# 64  World Environment Day (WED) is celebrated on t...
#
#                                      dropped_triplets  \
# 0   [(World Environment Day | WED, conferred by, U...
# 1   [(World Environment Day | WED, conferred by, U...
# 2   [(World Environment Day | WED, conferred by, U...
# 3   [(World Wildlife Day | WED, conferred by, Unit...
# 4   [(World Environment Day | WED, conferred by, U...
# ..                                                ...
# 60  [(Marine plastic pollution | marine pollution,...
# 61  [(Climate change | global warming, has cause, ...
# 62  [(Climate change | global warming, has cause, ...
# 63  [(--NME-- | WED chooses a new theme that major...
# 64  [(--NME-- | WED chooses a new theme that major...
#
#                                        total_triplets  \
# 0   [(World Environment Day, conferred by, United ...
# 1   [(World Environment Day, conferred by, United ...
# 2   [(World Environment Day, conferred by, United ...
# 3   [(World Environment Day, conferred by, United ...
# 4   [(World Environment Day, conferred by, United ...
# ..                                                ...
# 60  [(United Nations | United Nation, statement is...
# 61  [(United Nations | United Nation, statement is...
# 62  [(United Nations | United Nation, statement is...
# 63  [(United Nations | United Nation, statement is...
# 64  [(United Nations | United Nation, statement is...
#
#                                        triplet_scores
# 0             [0.5299999713897705, 0.550000011920929]
# 1            [0.4000000059604645, 0.3199999928474426]
# 2           [0.3799999952316284, 0.36000001430511475]
# 3          [0.28999999165534973, 0.25999999046325684]
# 4           [0.30000001192092896, 0.3100000023841858]
# ..                                                ...
# 60  [0.15000000596046448, 0.10000000149011612, 0.1...
# 61  [0.15000000596046448, 0.10000000149011612, 0.1...
# 62  [0.15000000596046448, 0.10000000149011612, 0.1...
# 63  [0.15000000596046448, 0.10000000149011612, 0.1...
# 64  [0.15000000596046448, 0.10000000149011612, 0.1...
#
# [65 rows x 7 columns]
