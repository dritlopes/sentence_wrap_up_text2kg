# %%
import json
import pprint
import pandas as pd

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)   
pd.set_option("display.max_columns", None)

# %%
df_beekeeping_additions = pd.read_csv("all_outputs/additions_relik-cie-xl_beekeeping.csv")

# %%
display(df_beekeeping_additions)
# Out:
#      text_type  output_step current_word  \
# 0   beekeeping            8           by
# 1   beekeeping           16       hives.
# 2   beekeeping           26        honey
# 3   beekeeping           28            A
# 4   beekeeping           30    maintains
# 5   beekeeping           38        honey
# 6   beekeeping           44         hive
# 7   beekeeping           46        (such
# 8   beekeeping           65           of
# 9   beekeeping           71          art
# 10  beekeeping           78         Back
# 11  beekeeping          114         when
# 12  beekeeping          146   beekeepers
# 13  beekeeping          163           is
#
# ...
